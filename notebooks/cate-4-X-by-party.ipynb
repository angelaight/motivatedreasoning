# %% [markdown]
# ## within party look for favoring plaintiff vs defendant

# %%
import causalml

from causalml.inference.meta import LRSRegressor
from causalml.inference.meta import XGBTRegressor, MLPTRegressor
from causalml.inference.meta import BaseXRegressor, BaseRRegressor, BaseSRegressor, BaseTRegressor
from causalml.match import NearestNeighborMatch, MatchOptimizer, create_table_one
from causalml.propensity import ElasticNetPropensityModel
from causalml.dataset import *
from causalml.metrics import *


from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
from sklearn.inspection import permutation_importance

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from xgboost import XGBRegressor
import warnings



import os, sys
import numpy as np
import pandas as pd
import pickle
import time
from datetime import datetime

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
from statsmodels.discrete.discrete_model import Logit

pd.set_option('display.max_columns', None)


module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import utils.explore_utils as eu

import re
import json
import shap
import seaborn as sns
import xgboost

# %%
df = pd.read_csv('/scratch/ns4486/cate_df.csv')

with open(r"/scratch/ns4486/cate_map_sample_50k.pkl", "rb") as input_file:
    cate_map = pickle.load(input_file)

with open('/scratch/ns4486/case_metadata.json') as f:
    case_meta_map = json.load(f)

# %%
# keep case-level features only
case_features_original = [
    'NOJ',
#     'PROSE',
    'CLASSACT',
    'JURIS',
    'TRCLACT',
    'statuscd',
    'PROCPROG',
#     'CIRCUIT',
    'ORIGIN',
#     'office',
    'NOS',
#     'district',
    'DISP',
#     'filing_year',
#     'district_year'
]

case_features = []

df_case = df.copy()


for case_feature in case_features_original:
    for feature in df.columns:
        if case_feature in feature:
            case_features.append(feature)

clf_cols = case_features + ['is_republican']
df_case = df_case[case_features]

# %%
col_desc = []

for col in case_features:    
    if 'CLASSACT' in col:
        col_desc.append(col)
        continue
    
    cat_col = col.split('_')[0]
    cat_val = col.split('_')[1]
    
    if any(letter.isalpha() for letter in cat_val):
        col_desc.append(col)
    else:
        cat_val = str(int(float(cat_val)))
        
        if cat_val not in case_meta_map[cat_col].keys():
            desc = cat_val + '_undefined undefined undefined'
        else:
            desc = case_meta_map[cat_col][cat_val]
        col_desc.append(cat_col + '_' + desc)

col_desc_map = dict(zip(df_case.columns, col_desc))
df_case = df_case.rename(columns = col_desc_map)

clf_cols = df_case.columns

df_case['is_republican'] = 1 - df['treatment']

# %%
cate_kind = 'X'
cate_threshold = 0.1

df_case['favors_plaintiff'] = np.ones(df.shape[0]) * -1
df_case['favors_plaintiff'][df[f'cate_{cate_kind}'] > cate_threshold] = 1
df_case['favors_plaintiff'][df[f'cate_{cate_kind}'] < -cate_threshold] = 0

df_case = df_case[df_case['favors_plaintiff'] != -1]

# %%
df_r = df_case[df_case['is_republican'] == 1]
df_d = df_case[df_case['is_republican'] != 1]

# %%
model_r = xgboost.XGBClassifier()
model_r.fit(df_r[clf_cols], df_r['favors_plaintiff'])

model_d = xgboost.XGBClassifier()
model_d.fit(df_d[clf_cols], df_d['favors_plaintiff'])
# Out:
# [14:32:02] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:32:03] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=2, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
def feature_importances(model, cols, top = 10):
    x = sorted(list(zip(cols, list(model.feature_importances_))), key = lambda x: -x[1])
    feature_imp_df = pd.DataFrame(x, columns = ['feature', 'importance'])
    feature_imp_df = feature_imp_df.sort_values(by = ['importance'], ascending = False)
    x = dict(x)
    
    
    plt.figure(figsize = (12, 7))
    sns.set_theme(style="whitegrid")
    sns.set_color_codes("pastel")

    sns.barplot(
        x="importance", 
        y="feature", 
        data=feature_imp_df.head(top),
        label="importance", 
        color="b"
    )

# %%
def calc_shap_values(model, df):
    bg = shap.maskers.Independent(df, max_samples=100)
    explainer = shap.Explainer(model, bg)
    shap_values = explainer(df)
    
    return shap_values

# %%
feature_importances(model_r, clf_cols)

# %%
feature_importances(model_d, clf_cols)

# %%
shap_values_r = calc_shap_values(model_r, df_r[clf_cols])
shap_values_d = calc_shap_values(model_d, df_d[clf_cols])

# %%
shap.plots.beeswarm(
    shap_values_r, 
    order=shap_values_r.abs.max(0), 
    max_display = 20
)

# %%
shap.plots.beeswarm(
    shap_values_d, 
    order=shap_values_d.abs.max(0), 
    max_display = 20
)

# %%
def top_favoring(shap_values, cols, kind, feature, top = 20):
    sort_order = False if kind == 'plaintiff' else True
    x = pd.DataFrame(shap_values.values, columns = list(cols))
    
    y = x.min() if sort_order else x.max()
    
    y = y.sort_values(ascending = sort_order).filter(regex=f'^{feature}')[:top]

#     y = {}
#     for col in cols:
#         z = x[col]
#         z[z > 0.2]
    
    return y

# %%
top_favoring(shap_values_r, clf_cols, kind = 'plaintiff', feature = 'NOS', top = 20)
# Out:
# NOS_BANKS AND BANKING                                                   4.228717
# NOS_CABLE/SATELLITE TV                                                  2.977483
# NOS_BANKRUPTCY APPEALS RULE 28 USC 158                                  2.703463
# NOS_CIVIL RIGHTS WELFARE                                                2.291818
# NOS_CONSTITUTIONALITY OF STATE STATUTES                                 2.244548
# NOS_OTHER PERSONAL PROPERTY DAMAGE                                      1.827750
# NOS_OTHER PERSONAL INJURY                                               1.735531
# NOS_PRISONER PETITIONS -HABEAS CORPUS                                   1.714518
# NOS_SECURITIES, COMMODITIES, EXCHANGE                                   1.701437
# NOS_TAX SUITS                                                           1.516785
# NOS_ADMINISTRATIVE PROCEDURE ACT/REVIEW OR APPEAL OF AGENCY DECISION    1.507967
# NOS_CIVIL RIGHTS ADA EMPLOYMENT                                         1.290444
# NOS_RENT, LEASE, EJECTMENT                                              1.239042
# NOS_PERSONAL INJURY -PRODUCT LIABILITY                                  1.196432
# NOS_S.S.I.D.                                                            1.069252
# NOS_PRISONER -CIVIL RIGHTS                                              0.999883
# NOS_ASSAULT, LIBEL, AND SLANDER                                         0.923736
# NOS_CIVIL RIGHTS VOTING                                                 0.835572
# NOS_CIVIL RIGHTS JOBS                                                   0.711537
# NOS_LABOR/MANAGEMENT RELATIONS ACT                                      0.624320
# dtype: float64

# %%
top_favoring(shap_values_r, clf_cols, kind = 'defendant', feature = 'NOS', top = 20)
# Out:
# NOS_LAND CONDEMNATION                         -4.037110
# NOS_BANKS AND BANKING                         -3.357385
# NOS_STOCKHOLDER'S SUITS                       -3.208482
# NOS_EDUCATION                                 -3.149952
# NOS_RAILWAY LABOR ACT                         -2.976669
# NOS_TRADEMARK                                 -2.839731
# NOS_ENVIRONMENTAL MATTERS                     -2.546557
# NOS_HEALTH CARE / PHARM                       -2.431645
# NOS_MARINE CONTRACT ACTIONS                   -2.396795
# NOS_ARBITRATION                               -2.280330
# NOS_OTHER STATUTORY ACTIONS                   -2.235109
# NOS_LABOR/MANAGEMENT REPORT & DISCLOSURE      -2.227011
# NOS_CONSUMER CREDIT                           -2.133638
# NOS_HIA (1395 FF)/ MEDICARE                   -2.131958
# NOS_RECOVERY OF DEFAULTED STUDENT LOANS       -1.725895
# NOS_ANTITRUST                                 -1.515119
# NOS_AGRICULTURAL ACTS - 891                   -1.360191
# NOS_EMPLOYEE RETIREMENT INCOME SECURITY ACT   -1.170721
# NOS_FORECLOSURE                               -1.070358
# NOS_PRISONER PETITIONS -VACATE SENTENCE       -1.063600
# dtype: float64

# %%
top_favoring(shap_values_d, clf_cols, kind = 'plaintiff', feature = 'NOS', top = 20)
# Out:
# NOS_OTHER PERSONAL PROPERTY DAMAGE                                      3.857558
# NOS_BANKRUPTCY APPEALS RULE 28 USC 158                                  2.179793
# NOS_CONSTITUTIONALITY OF STATE STATUTES                                 1.996667
# NOS_TAX SUITS                                                           1.945190
# NOS_MOTOR VEHICLE PERSONAL INJURY                                       1.786898
# NOS_CIVIL RIGHTS ADA EMPLOYMENT                                         1.693471
# NOS_HABEAS CORPUS: DEATH PENALTY                                        1.661741
# NOS_CABLE/SATELLITE TV                                                  1.658533
# NOS_CIVIL RIGHTS WELFARE                                                1.636673
# NOS_TORTS TO LAND                                                       1.461228
# NOS_CIVIL RIGHTS ACCOMMODATIONS                                         1.324958
# NOS_ANTITRUST                                                           1.255676
# NOS_OTHER CIVIL RIGHTS                                                  1.188303
# NOS_PERSONAL INJURY -PRODUCT LIABILITY                                  1.169152
# NOS_LABOR/MANAGEMENT RELATIONS ACT                                      1.159347
# NOS_OVERPAYMENTS UNDER THE MEDICARE ACT                                 1.013205
# NOS_FOOD AND DRUG ACTS                                                  1.008941
# NOS_ADMINISTRATIVE PROCEDURE ACT/REVIEW OR APPEAL OF AGENCY DECISION    1.005713
# NOS_PRISONER PETITIONS -VACATE SENTENCE                                 0.979673
# NOS_PRISONER PETITIONS -HABEAS CORPUS                                   0.925687
# dtype: float64

# %%
top_favoring(shap_values_d, clf_cols, kind = 'defendant', feature = 'NOS', top = 20)
# Out:
# NOS_LABOR/MANAGEMENT REPORT & DISCLOSURE     -3.869606
# NOS_LAND CONDEMNATION                        -3.004096
# NOS_EDUCATION                                -2.413576
# NOS_OTHER FORFEITURE AND PENALTY SUITS       -2.394406
# NOS_IRS 3RD PARTY SUITS 26 USC 7609          -2.006453
# NOS_AGRICULTURAL ACTS - 891                  -1.995328
# NOS_OTHER STATUTORY ACTIONS                  -1.895053
# NOS_STOCKHOLDER'S SUITS                      -1.814442
# NOS_ENVIRONMENTAL MATTERS                    -1.782191
# NOS_DEPORTATION                              -1.694449
# NOS_TORT PRODUCT LIABILITY                   -1.669627
# NOS_TRADEMARK                                -1.429563
# NOS_HIA (1395 FF)/ MEDICARE                  -1.358501
# NOS_RAILWAY LABOR ACT                        -1.210720
# NOS_HEALTH CARE / PHARM                      -1.184153
# NOS_R.S.I.                                   -1.057792
# NOS_D.I.W.C./D.I.W.W.                        -1.047876
# NOS_PATENT                                   -0.980933
# NOS_PRISONER PETITIONS -MANDAMUS AND OTHER   -0.820084
# NOS_CIVIL RIGHTS VOTING                      -0.815180
# dtype: float64
